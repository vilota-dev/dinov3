# %% [markdown]
# ### Import Libraries & Model

# %% [markdown]
# ## Process Flow Overview
#
# ```mermaid
# flowchart TD
#     A[Data Input\nCSV annotations + image folders] --> B[Data Cleaning\nDrop unused columns, fill NaN, normalize labels]
#     B --> C[Image Matching\nMap SN + position to image files]
#     C --> D[Label Mapping\nConvert annotation text to class index]
#     D --> E[Train/Validation Split\nStratified by label]
#     E --> F[Dataset + DataLoader\nReturn image tensor, patch mask, label, Laplacian tensor]
#     F --> G[Model Input\nDINOv3 backbone + patch mask + Laplacian]
#     G --> H[Classifier Head\nFused features -> residual MLP]
#     H --> I{Training or Inference?}
#
#     I -->|Training| J[Loss + Optimizer\nCrossEntropyLoss + AdamW]
#     J --> K[Backpropagation\nUpdate classifier head]
#     K --> L[Validation Loop\nAccuracy, precision, macro F1]
#     L --> M[Early Stopping\nSave best classifier head]
#     M --> N[Training Outputs\nCheckpoint .pth + metrics + confusion matrix]
#
#     I -->|Inference| O[Load Saved Head\nclassifier_head state_dict]
#     O --> P[Unseen Images\nRecursive folder scan]
#     P --> Q[Prediction Logic\nPatch mask + Laplacian + softmax]
#     Q --> R[Decision Action\nPass / Review / Defect label]
#     R --> S[Prediction Output\nCSV summary for batch review]
#
#     N --> T[Final Action\nUse best checkpoint for deployment]
#     S --> T
# ```

# %%
import os
import sys
import cv2
import glob
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from sklearn.model_selection import train_test_split
import pandas as pd
from pathlib import Path

# Explicitly set the root directory since __file__ isn't available in Jupyter
root_dir = "/home/vilota/mingjie/dinov3"

# Add the root directory to Python's path so it can find the 'dinov3' module
if root_dir not in sys.path:
    sys.path.append(root_dir)
    
from dinov3.hub.backbones import dinov3_vith16plus, Weights
from torch.optim.lr_scheduler import CosineAnnealingLR

import wandb
wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/vilota/.netrc.
# wandb: Currently logged in as: mingjiehu5 (mingjiehu5-nanyang-technological-university-singapore) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### Wandb Record

# %%
# Initialize a new experiment run
wandb.init(
    project="dinov3-blur-detection",  # Group name for your experiments
    name="vith16plus-multiclass-run1", # Name of this specific trial run
    config={
        "architecture": "dinov3_vith16plus",
    }
)

# Optional: You can access these variables anywhere using wandb.config
config = wandb.config
# Out:
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>/home/vilota/mingjie/dinov3/scripts/wandb/run-20260604_181916-zk0n6l48</code>
# Syncing run <strong><a href='https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection/runs/zk0n6l48' target="_blank">vith16plus-multiclass-run1</a></strong> to <a href='https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection' target="_blank">https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection</a>
#  View run at <a href='https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection/runs/zk0n6l48' target="_blank">https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection/runs/zk0n6l48</a>

# %% [markdown]
# ### DINOv3 + Classifier Model

# %%
# ==========================================
# 1. DINOv3 MODEL DEFINITION
# ==========================================

class ResidualBlock(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.block = nn.Sequential(
            nn.Linear(input_dim, output_dim),
            nn.BatchNorm1d(output_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(output_dim, output_dim),
            nn.BatchNorm1d(output_dim),
        )

        self.shortcut = nn.Sequential(
            nn.Linear(input_dim, output_dim),
            nn.BatchNorm1d(output_dim),
        )

        self.relu = nn.ReLU()

    def forward(self, x):
        return self.relu(self.block(x) + self.shortcut(x))


class BlurClassifier(nn.Module):
    # Added weights_path=None to the arguments
    def __init__(self, backbone_name="dinov3_vith16plus", freeze_backbone=True, num_classes=4, weights_path=None):
        super().__init__()
        
        print(f"Loading DINOv3 Backbone: {backbone_name}...")
        if backbone_name == "dinov3_vith16plus":
            # If a local path is provided, pass it to the weights argument!
            weights_arg = weights_path if weights_path else Weights.LVD1689M
            self.backbone = dinov3_vith16plus(pretrained=True, weights=weights_arg)
        else:
            raise ValueError(f"Unsupported backbone: {backbone_name}")
            
        if freeze_backbone:
            for param in self.backbone.parameters():
                param.requires_grad = False
                
        embed_dim = self.backbone.embed_dim
        linear_input_dim = 2 * embed_dim

        laplacian_input_dim = 196

        self.laplacian_projector = nn.Sequential(
            nn.Linear(laplacian_input_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
        )

        fused_input_dim = linear_input_dim + 128
        
        self.classifier_head = nn.Sequential(
            nn.Linear(fused_input_dim, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            ResidualBlock(2048, 1024),
            nn.Linear(1024, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes) # Multi-class output
        )



    def forward(self, x, patch_mask, laplacian_tensor):
        features = self.backbone.forward_features(x)
        cls_token = features["x_norm_clstoken"]       
        patch_tokens = features["x_norm_patchtokens"] 
        
        mask_weights = patch_mask.float().unsqueeze(-1)
        weighted_patches = patch_tokens * mask_weights
        
        summed_patches = weighted_patches.sum(dim=1) 
        valid_patch_count = mask_weights.sum(dim=1) + 1e-6
        masked_patch_mean = summed_patches / valid_patch_count

        dino_feature = torch.cat([cls_token, masked_patch_mean], dim=1)
        

        pooled_laplacian = F.avg_pool2d(laplacian_tensor, kernel_size=16, stride=16)
        pooled_laplacian = F.adaptive_avg_pool2d(pooled_laplacian, (14, 14))
        flat_laplacian = pooled_laplacian.view(pooled_laplacian.size(0), -1)
        laplacian_features = self.laplacian_projector(flat_laplacian)

        fused_input = torch.cat([dino_feature, laplacian_features], dim=1)


        logits = self.classifier_head(fused_input)
        
        return logits

# %% [markdown]
# ### CV2 Process & Mask Generator

# %%
# ==========================================
# 2. DATASET & MASK GENERATOR
# ==========================================
def get_horizontal_patch_mask(image_path, image_size=224, patch_size=16, threshold=50):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Could not load image at {image_path}")
        
    img = cv2.resize(img, (image_size, image_size))
    sobel_y = cv2.Sobel(img, cv2.CV_64F, dx=0, dy=1, ksize=3)
    abs_sobel_y = np.absolute(sobel_y)
    sobel_8u = np.uint8(255 * abs_sobel_y / np.max(abs_sobel_y))
    
    _, binary_mask = cv2.threshold(sobel_8u, threshold, 255, cv2.THRESH_BINARY)
    mask_tensor = torch.tensor(binary_mask, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    
    patch_mask_2d = F.max_pool2d(mask_tensor, kernel_size=patch_size, stride=patch_size)
    patch_mask_flat = patch_mask_2d.view(-1) > 0 
    
    return patch_mask_flat

class BlurDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        
        # 1. Process Image
        pil_image = Image.open(img_path).convert("RGB")
        if self.transform:
            pixel_values = self.transform(pil_image)
            
        # 2. Generate Mask
        patch_mask = get_horizontal_patch_mask(img_path)
        
        # 3. Label (0.0 for Sharp, 1.0 for Blur)
        label_tensor = torch.tensor(label, dtype=torch.long)
        
        laplacian_kernel = torch.tensor([[[[0, 1, 0],
                                           [0, -2, 0],
                                           [0, 1, 0]]]], dtype=torch.float32)
        
        gray_pixel_values = T.functional.rgb_to_grayscale(pil_image)
        gray_tensor = TF.to_tensor(gray_pixel_values)
        
        laplacian_tensor = F.conv2d(gray_tensor.unsqueeze(0), laplacian_kernel, padding=1).squeeze(0)
        laplacian_tensor =  torch.abs(laplacian_tensor)

        return pixel_values, patch_mask, label_tensor, laplacian_tensor

# %% [markdown]
# ### Early Stop

# %%
class EarlyStopping:
    def __init__(self, patience=50, min_delta=0, save_path="dino_classifier_head_multiclass.pth"):
        self.patience = patience
        self.min_delta = min_delta
        self.base_save_path = save_path  
        self.counter = 0
        self.best_precision = 0.0  
        self.early_stop = False

    def __call__(self, val_precision, model_head, epoch):
        if val_precision > (self.best_precision + self.min_delta):
            print(f"-> Validation precision improved ({self.best_precision:.4f} --> {val_precision:.4f}).")
            self.best_precision = val_precision
            self.counter = 0
            
            # Append epoch number dynamically
            path_obj = Path(self.base_save_path)
            new_filename = f"{path_obj.stem}_epoch_{epoch}{path_obj.suffix}"
            current_save_path = str(path_obj.with_name(new_filename))
            
            print(f"Saving classifier head to {current_save_path}")
            torch.save(model_head.state_dict(), current_save_path)
        else:
            self.counter += 1
            print(f"-> EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True

# %%
from sklearn.metrics import precision_score
from torch.optim.lr_scheduler import CosineAnnealingLR
from sklearn.utils.class_weight import compute_class_weight

# ==========================================
# 3. TRAINING LOOP
# ==========================================
def train_model(model, train_loader, val_loader, device, epochs=500, lr=5e-4, save_path="classifier_head.pth"):
    # Heavily penalize missing defects by adjusting the target loss multipliers
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    weights_tensor = torch.FloatTensor(class_weights).to(device)

    optimizer = torch.optim.AdamW(model.classifier_head.parameters(), lr=lr, weight_decay=1e-2)
    criterion = nn.CrossEntropyLoss(weight=weights_tensor)
    scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=1e-6)
    
    # Initialize the precision-monitoring early stopper
    early_stopper = EarlyStopping(patience=50, save_path=save_path)
    wandb.watch(model.classifier_head, log="all", log_freq=10)

    for epoch in range(epochs):
        # --- TRAINING PHASE ---
        model.train()
        train_loss = 0.0
        train_correct = 0
        total_train = 0
        
        for pixel_values, patch_mask, labels, laplacian_tensor in train_loader:
            pixel_values = pixel_values.to(device)
            patch_mask = patch_mask.to(device)
            labels = labels.to(device, dtype=torch.long)
            laplacian_tensor = laplacian_tensor.to(device)

            optimizer.zero_grad()
            
            logits = model(pixel_values, patch_mask, laplacian_tensor)
            loss = criterion(logits, labels)
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * pixel_values.size(0)
            
            preds = torch.argmax(logits, dim=1)
            train_correct += (preds == labels).sum().item()
            total_train += labels.size(0)

        avg_train_loss = train_loss / total_train
        train_acc = train_correct / total_train

        # --- VALIDATION PHASE ---
        model.eval()
        val_loss = 0.0
        val_correct = 0
        total_val = 0
        
        # Lists to store metrics across the entire validation dataset for this epoch
        val_preds = []
        val_labels_list = []
        
        with torch.no_grad():
            for pixel_values, patch_mask, labels, laplacian_tensor in val_loader:
                pixel_values = pixel_values.to(device)
                patch_mask = patch_mask.to(device)
                labels = labels.to(device, dtype=torch.long)
                laplacian_tensor = laplacian_tensor.to(device)

                logits = model(pixel_values, patch_mask, laplacian_tensor)
                loss = criterion(logits, labels)
                
                val_loss += loss.item() * pixel_values.size(0)
                
                preds = torch.argmax(logits, dim=1)
                val_correct += (preds == labels).sum().item()
                total_val += labels.size(0)
                
                # Append arrays to evaluate holistic macro precision metrics
                val_preds.extend(preds.cpu().numpy())
                val_labels_list.extend(labels.cpu().numpy())

        avg_val_loss = val_loss / total_val
        val_acc = val_correct / total_val
        
        # Calculate precision specifically for the 'o' (OK, index 0) class
        y_true = np.array(val_labels_list)
        y_pred = np.array(val_preds)
        ok_precision = precision_score(y_true == 0, y_pred == 0, pos_label=True, zero_division=0)
        macro_f1 = precision_score(y_true, y_pred, average='macro', zero_division=0)

        print(f"Epoch [{epoch+1}/{epochs}] | "
              f"Train Loss: {avg_train_loss:.4f}, Acc: {train_acc:.4f} | "
              f"Val Loss: {avg_val_loss:.4f}, Acc: {val_acc:.4f} | "
              f"OK Precision: {ok_precision:.4f}, Macro F1: {macro_f1:.4f}")

        # Update learning rate scheduler steps
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']

        # Log metrics safely to the cloud dashboard
        wandb.log({
            "epoch": epoch + 1,
            "train/loss": avg_train_loss,
            "train/accuracy": train_acc,
            "val/loss": avg_val_loss,
            "val/accuracy": val_acc,
            "val/macro_f1": macro_f1,
            "val/ok_precision": ok_precision,
            "learning_rate": current_lr,
            "early_stopping_counter": early_stopper.counter
        })

        # Evaluate checkpoint against best precision criteria
        early_stopper(macro_f1, model.classifier_head, epoch=epoch + 1)

        if early_stopper.early_stop:
            print("Early stopping triggered. Training stopped.")
            break

# %% [markdown]
# ### Multi Class Mapping

# %%
# Define the multi-class mapping based on your human annotations
'''
LABEL_MAP = {
    'o':  0, # ok
    'sf': 1, # slightly far
    'mf': 2, # medium far
    'xf': 3, # extremely far
    'sn': 4, # slightly near
    'mn': 5, # medium near
    'xn': 6  # extremely near
}
'''
LABEL_MAP = {
    'f': 0, # far
    'o': 1, # ok
    'sn': 2, # slightly near
    'n': 3  # near
}
NUM_CLASSES = len(LABEL_MAP)

# %% [markdown]
# ### Data Cleaning & Finding

# %%
analysis_positions = [1, 3, 5, 7, 9]

manual_path = "/home/vilota/566-qa-2/merge/remapped_merged_dataset.csv"

df = pd.read_csv(manual_path)

df = df.rename(columns={"????": "Capture Time", "??": "Grade", "NG??": "NG", "???": "SN", "??.1": "Short SN Pairing"})
column_to_drop = ['Capture Time', 'Grade', 'NG', 'Short SN Pairing', 'Full SN', '???.1', '???.2', '???_Focus', '???_Focus.1', 'AA?_??S', 'AA?_??S2', 'AA?_??T', 'AA?_??T2', 'AA?_??S.1', 'AA?_??T.1', 'AA?_??S.2', 'AA?_??T.2', 'AA?_??S.3', 'AA?_??T.3', 'AA?_??S.4', 'AA?_??T.4', 'AA?_Tilt-X', 'AA?_Tilt-Y', 'AA?_OC-X', 'AA?_OC-Y', 'AA?_???X', 'AA?_???Y', 'AA?_??0.5F-S', 'AA?_??0.5F-T', 'AA?_??0.5F-S.1', 'AA?_??0.5F-T.1', 'AA?_??0.5F-S.2', 'AA?_??0.5F-T.2', 'AA?_??0.5F-S.3', 'AA?_??0.5F-T.3', 'AA?_????', 'AA?_????.1', 'AA?_????.2', 'AA?_????.3', 'AA?_??0.5??', 'AA?_??0.5??.1', 'AA?_??0.5??.2', 'AA?_??0.5??.3']
df = df.drop(columns=column_to_drop, errors='ignore')
df = df.fillna("o")

pos_columns = ['pos 1', 'pos 3', 'pos 5', 'pos 7', 'pos 9']

for col in pos_columns:
    if col in df.columns:
        df[col] = df[col].astype(str).str.split('/').str[0].str.strip()

df['SN'] = df['SN'].astype(str).str.split('/').str[0].str.strip().str.upper().str.replace(r'\.0$', '', regex=True)

# ---------------------------------------------------------
# DATA EXTRACTION TO PYTORCH DATASET
# ---------------------------------------------------------
IMAGE_DIRS = [
    "/home/vilota/566-qa-2/618D/processed_img", 
    "/home/vilota/566-qa-2/619D/processed_img",
    "/home/vilota/566-qa-2/620D/processed_img"
]
print(f"Recursively indexing all images in {IMAGE_DIRS}...")

# Build a dictionary mapping 'filename.ext' -> '/absolute/path/to/nested/folder/filename.ext'
image_path_map = {}
valid_extensions = {'.bmp', '.png', '.jpg', '.jpeg'}

for IMAGE_DIR in IMAGE_DIRS:
    for p in Path(IMAGE_DIR).rglob('*'):
        if p.is_file() and p.suffix.lower() in valid_extensions:
            image_path_map[p.name] = str(p)

print(f"Found {len(image_path_map)} total image files across all subfolders.")

valid_images = []
valid_labels = []

# Map from the position number to the column name in df
pos_mapping = {
    1: 'pos 1',
    3: 'pos 3',
    5: 'pos 5',
    7: 'pos 7',
    9: 'pos 9'
}

missing_images = 0
for idx, row in df.iterrows():
    sn = row['SN']
    for pos_num, col_name in pos_mapping.items():
        if col_name in row:
            annotation = str(row[col_name]).strip().lower()
            
            if annotation in LABEL_MAP:
                # Define all possible filename structures for this SN/Pos
                possible_names = [
                    f"{sn}-{pos_num}.bmp",
                    f"{sn}-{pos_num}.png",
                    f"processed_{sn}-{pos_num}.png"
                ]
                
                # Check our index to see if any of these filenames exist anywhere
                found_path = None
                for name in possible_names:
                    if name in image_path_map:
                        found_path = image_path_map[name]
                        break # Found it! Stop checking alternatives.
                
                if found_path:
                    valid_images.append(found_path)
                    valid_labels.append(LABEL_MAP[annotation])
                else:
                    missing_images += 1
                    
if missing_images > 0:
    print(f"Warning: {missing_images} labeled items in the CSV could not be matched to an image file.")
    
if not valid_images:
    raise ValueError("No valid images found! Check your IMAGE_DIR and filename conventions.")
# Out:
# Recursively indexing all images in ['/home/vilota/566-qa-2/618D/processed_img', '/home/vilota/566-qa-2/619D/processed_img', '/home/vilota/566-qa-2/620D/processed_img']...
# Found 5465 total image files across all subfolders.
# Warning: 90 labeled items in the CSV could not be matched to an image file.

# %% [markdown]
# ### Split Data

# %%
X_train, X_val, y_train, y_val = train_test_split(valid_images, valid_labels, test_size=0.2, random_state=42, stratify=valid_labels)

print(f"Dataset Loaded: {len(X_train)} Train | {len(X_val)} Validation")
# Out:
# Dataset Loaded: 2040 Train | 510 Validation

# %% [markdown]
# ### Data Loader

# %%
# ---------------------------------------------------------
# TRANSFORMS, DATALOADERS & EXECUTION
# ---------------------------------------------------------
train_transform = T.Compose([
    T.Resize((224, 224), interpolation=T.InterpolationMode.BICUBIC),
    T.RandomHorizontalFlip(p=0.5),
    T.RandomVerticalFlip(p=0.5),
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])

val_transform = T.Compose([
    T.Resize((224, 224), interpolation=T.InterpolationMode.BICUBIC),
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])

train_dataset = BlurDataset(X_train, y_train, transform=train_transform)
val_dataset = BlurDataset(X_val, y_val, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=8)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, num_workers=8)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define where you saved the downloaded .pth file
LOCAL_WEIGHTS = "/home/vilota/mingjie/dinov3/weights/dinov3_vith16plus_pretrain_lvd1689m-7c1da9a5.pth" 

model = BlurClassifier(
    backbone_name="dinov3_vith16plus", 
    freeze_backbone=True, 
    num_classes=NUM_CLASSES,
    weights_path=LOCAL_WEIGHTS  # <-- Pass the local path here
).to(device)
# Out:
# Using device: cuda
# Loading DINOv3 Backbone: dinov3_vith16plus...

# %% [markdown]
# ### Start Training

# %%
print("\nStarting Training...")
train_model(
    model=model, 
    train_loader=train_loader, 
    val_loader=val_loader, 
    device=device,
    epochs=500, 
    lr=1e-2, 
    save_path=f"dino_classifier_head_multiclass.pth"
)
# Out:
# Starting Training...
# Epoch [1/500] | Train Loss: 1.4407, Acc: 0.5873 | Val Loss: 0.8973, Acc: 0.5824 | OK Precision: 0.0541, Macro F1: 0.2958
# -> Validation precision improved (0.0000 --> 0.2958).
# Saving classifier head to dino_classifier_head_multiclass_epoch_1.pth
# Epoch [2/500] | Train Loss: 1.0615, Acc: 0.6500 | Val Loss: 0.9399, Acc: 0.4725 | OK Precision: 0.0980, Macro F1: 0.3093
# -> Validation precision improved (0.2958 --> 0.3093).
# Saving classifier head to dino_classifier_head_multiclass_epoch_2.pth
# Epoch [3/500] | Train Loss: 0.9938, Acc: 0.6770 | Val Loss: 0.8366, Acc: 0.7294 | OK Precision: 1.0000, Macro F1: 0.5721
# -> Validation precision improved (0.3093 --> 0.5721).
# Saving classifier head to dino_classifier_head_multiclass_epoch_3.pth
# Epoch [4/500] | Train Loss: 0.9578, Acc: 0.6824 | Val Loss: 0.8123, Acc: 0.7078 | OK Precision: 0.4545, Macro F1: 0.4063
# -> EarlyStopping counter: 1 out of 50
# Epoch [5/500] | Train Loss: 0.8424, Acc: 0.7319 | Val Loss: 0.7516, Acc: 0.5137 | OK Precision: 0.3571, Macro F1: 0.3775
# -> EarlyStopping counter: 2 out of 50
# Epoch [6/500] | Train Loss: 0.8712, Acc: 0.7294 | Val Loss: 0.8139, Acc: 0.4941 | OK Precision: 0.2000, Macro F1: 0.3431
# -> EarlyStopping counter: 3 out of 50
# Epoch [7/500] | Train Loss: 0.7710, Acc: 0.7402 | Val Loss: 0.6735, Acc: 0.8235 | OK Precision: 0.5556, Macro F1: 0.4750
# -> EarlyStopping counter: 4 out of 50
# Epoch [8/500] | Train Loss: 0.8141, Acc: 0.7475 | Val Loss: 0.7142, Acc: 0.6941 | OK Precision: 0.1923, Macro F1: 0.3624
# -> EarlyStopping counter: 5 out of 50
# Epoch [9/500] | Train Loss: 0.7997, Acc: 0.7402 | Val Loss: 0.6556, Acc: 0.8412 | OK Precision: 0.7143, Macro F1: 0.5853
# -> Validation precision improved (0.5721 --> 0.5853).
# Saving classifier head to dino_classifier_head_multiclass_epoch_9.pth
# Epoch [10/500] | Train Loss: 0.8432, Acc: 0.7422 | Val Loss: 0.7144, Acc: 0.7608 | OK Precision: 0.3571, Macro F1: 0.4681
# -> EarlyStopping counter: 1 out of 50
# Epoch [11/500] | Train Loss: 0.7801, Acc: 0.7422 | Val Loss: 0.8015, Acc: 0.7294 | OK Precision: 0.1282, Macro F1: 0.3483
# -> EarlyStopping counter: 2 out of 50
# Epoch [12/500] | Train Loss: 0.7830, Acc: 0.7534 | Val Loss: 0.7793, Acc: 0.7333 | OK Precision: 0.2632, Macro F1: 0.3961
# -> EarlyStopping counter: 3 out of 50
# Epoch [13/500] | Train Loss: 0.8447, Acc: 0.7221 | Val Loss: 0.7376, Acc: 0.6627 | OK Precision: 0.0758, Macro F1: 0.5888
# -> Validation precision improved (0.5853 --> 0.5888).
# Saving classifier head to dino_classifier_head_multiclass_epoch_13.pth
# Epoch [14/500] | Train Loss: 0.7901, Acc: 0.7441 | Val Loss: 0.6517, Acc: 0.7333 | OK Precision: 0.2632, Macro F1: 0.3868
# -> EarlyStopping counter: 1 out of 50
# Epoch [15/500] | Train Loss: 0.7660, Acc: 0.7289 | Val Loss: 0.9100, Acc: 0.6275 | OK Precision: 0.1316, Macro F1: 0.3316
# -> EarlyStopping counter: 2 out of 50
# Epoch [16/500] | Train Loss: 0.7875, Acc: 0.7569 | Val Loss: 0.6179, Acc: 0.8059 | OK Precision: 0.2500, Macro F1: 0.4815
# -> EarlyStopping counter: 3 out of 50
# Epoch [17/500] | Train Loss: 0.7884, Acc: 0.7260 | Val Loss: 0.6743, Acc: 0.8020 | OK Precision: 0.2000, Macro F1: 0.4698
# -> EarlyStopping counter: 4 out of 50
# Epoch [18/500] | Train Loss: 0.7973, Acc: 0.7319 | Val Loss: 0.7068, Acc: 0.7137 | OK Precision: 0.3125, Macro F1: 0.4713
# -> EarlyStopping counter: 5 out of 50
# Epoch [19/500] | Train Loss: 0.7229, Acc: 0.7833 | Val Loss: 0.8415, Acc: 0.6176 | OK Precision: 0.0667, Macro F1: 0.3373
# -> EarlyStopping counter: 6 out of 50
# Epoch [20/500] | Train Loss: 0.7581, Acc: 0.7059 | Val Loss: 0.7076, Acc: 0.7745 | OK Precision: 0.1017, Macro F1: 0.4807
# -> EarlyStopping counter: 7 out of 50
# Epoch [21/500] | Train Loss: 0.7429, Acc: 0.7593 | Val Loss: 0.6891, Acc: 0.8490 | OK Precision: 0.2941, Macro F1: 0.5528
# -> EarlyStopping counter: 8 out of 50
# Epoch [22/500] | Train Loss: 0.7256, Acc: 0.7735 | Val Loss: 0.6640, Acc: 0.7059 | OK Precision: 0.2069, Macro F1: 0.4546
# -> EarlyStopping counter: 9 out of 50
# Epoch [23/500] | Train Loss: 0.7285, Acc: 0.7578 | Val Loss: 0.7176, Acc: 0.7784 | OK Precision: 0.2083, Macro F1: 0.4469
# -> EarlyStopping counter: 10 out of 50
# Epoch [24/500] | Train Loss: 0.7689, Acc: 0.7456 | Val Loss: 0.6472, Acc: 0.8549 | OK Precision: 0.3333, Macro F1: 0.4905
# -> EarlyStopping counter: 11 out of 50
# Epoch [25/500] | Train Loss: 0.7308, Acc: 0.7574 | Val Loss: 0.7260, Acc: 0.8078 | OK Precision: 0.3846, Macro F1: 0.4651
# -> EarlyStopping counter: 12 out of 50
# Epoch [26/500] | Train Loss: 0.7363, Acc: 0.7711 | Val Loss: 0.6306, Acc: 0.8294 | OK Precision: 0.2000, Macro F1: 0.4653
# -> EarlyStopping counter: 13 out of 50
# Epoch [27/500] | Train Loss: 0.7367, Acc: 0.7456 | Val Loss: 0.6248, Acc: 0.8216 | OK Precision: 0.2778, Macro F1: 0.4100
# -> EarlyStopping counter: 14 out of 50
# Epoch [28/500] | Train Loss: 0.7701, Acc: 0.7358 | Val Loss: 0.6175, Acc: 0.8294 | OK Precision: 0.3846, Macro F1: 0.5192
# -> EarlyStopping counter: 15 out of 50
# Epoch [29/500] | Train Loss: 0.7228, Acc: 0.7461 | Val Loss: 0.6532, Acc: 0.8373 | OK Precision: 0.5000, Macro F1: 0.4570
# -> EarlyStopping counter: 16 out of 50
# Epoch [30/500] | Train Loss: 0.6935, Acc: 0.7819 | Val Loss: 0.6345, Acc: 0.8059 | OK Precision: 0.3571, Macro F1: 0.4963
# -> EarlyStopping counter: 17 out of 50
# Epoch [31/500] | Train Loss: 0.7385, Acc: 0.7583 | Val Loss: 0.6347, Acc: 0.8314 | OK Precision: 0.2941, Macro F1: 0.5233
# -> EarlyStopping counter: 18 out of 50
# Epoch [32/500] | Train Loss: 0.7043, Acc: 0.7667 | Val Loss: 0.6403, Acc: 0.8294 | OK Precision: 0.3846, Macro F1: 0.4700
# -> EarlyStopping counter: 19 out of 50
# Epoch [33/500] | Train Loss: 0.6974, Acc: 0.7574 | Val Loss: 0.7156, Acc: 0.8020 | OK Precision: 0.1579, Macro F1: 0.3827
# -> EarlyStopping counter: 20 out of 50
# Epoch [34/500] | Train Loss: 0.6775, Acc: 0.7760 | Val Loss: 0.6127, Acc: 0.8333 | OK Precision: 0.4545, Macro F1: 0.5393
# -> EarlyStopping counter: 21 out of 50
# Epoch [35/500] | Train Loss: 0.6731, Acc: 0.7632 | Val Loss: 0.7267, Acc: 0.8353 | OK Precision: 0.2381, Macro F1: 0.4831
# -> EarlyStopping counter: 22 out of 50
# Epoch [36/500] | Train Loss: 0.6809, Acc: 0.7794 | Val Loss: 0.6648, Acc: 0.8059 | OK Precision: 0.4167, Macro F1: 0.5369
# -> EarlyStopping counter: 23 out of 50
# Epoch [37/500] | Train Loss: 0.7647, Acc: 0.7500 | Val Loss: 0.6240, Acc: 0.7902 | OK Precision: 0.2273, Macro F1: 0.3928
# -> EarlyStopping counter: 24 out of 50
# Epoch [38/500] | Train Loss: 0.7044, Acc: 0.7799 | Val Loss: 0.7228, Acc: 0.8549 | OK Precision: 0.4167, Macro F1: 0.4477
# -> EarlyStopping counter: 25 out of 50
# Epoch [39/500] | Train Loss: 0.6770, Acc: 0.7613 | Val Loss: 0.6118, Acc: 0.8098 | OK Precision: 0.3571, Macro F1: 0.5391
# -> EarlyStopping counter: 26 out of 50
# Epoch [40/500] | Train Loss: 0.6441, Acc: 0.7574 | Val Loss: 0.6653, Acc: 0.7353 | OK Precision: 0.4545, Macro F1: 0.4722
# -> EarlyStopping counter: 27 out of 50
# Epoch [41/500] | Train Loss: 0.6779, Acc: 0.7451 | Val Loss: 0.6325, Acc: 0.7882 | OK Precision: 0.3846, Macro F1: 0.4909
# -> EarlyStopping counter: 28 out of 50
# Epoch [42/500] | Train Loss: 0.6758, Acc: 0.7672 | Val Loss: 0.6744, Acc: 0.7118 | OK Precision: 0.2941, Macro F1: 0.4360
# -> EarlyStopping counter: 29 out of 50
# Epoch [43/500] | Train Loss: 0.7048, Acc: 0.7520 | Val Loss: 0.6757, Acc: 0.8333 | OK Precision: 0.4167, Macro F1: 0.5263
# -> EarlyStopping counter: 30 out of 50
# Epoch [44/500] | Train Loss: 0.7455, Acc: 0.7333 | Val Loss: 0.7784, Acc: 0.6941 | OK Precision: 0.6250, Macro F1: 0.4774
# -> EarlyStopping counter: 31 out of 50
# Epoch [45/500] | Train Loss: 0.6573, Acc: 0.7804 | Val Loss: 0.6714, Acc: 0.8294 | OK Precision: 0.3333, Macro F1: 0.4904
# -> EarlyStopping counter: 32 out of 50
# Epoch [46/500] | Train Loss: 0.6573, Acc: 0.7691 | Val Loss: 0.6503, Acc: 0.8706 | OK Precision: 0.5000, Macro F1: 0.5733
# -> EarlyStopping counter: 33 out of 50
# Epoch [47/500] | Train Loss: 0.6644, Acc: 0.7838 | Val Loss: 0.6148, Acc: 0.7941 | OK Precision: 0.2727, Macro F1: 0.4810
# -> EarlyStopping counter: 34 out of 50
# Epoch [48/500] | Train Loss: 0.6612, Acc: 0.7833 | Val Loss: 0.6734, Acc: 0.8549 | OK Precision: 0.5556, Macro F1: 0.5433
# -> EarlyStopping counter: 35 out of 50
# Epoch [49/500] | Train Loss: 0.6604, Acc: 0.7466 | Val Loss: 0.6940, Acc: 0.7745 | OK Precision: 0.3333, Macro F1: 0.4924
# -> EarlyStopping counter: 36 out of 50
# Epoch [50/500] | Train Loss: 0.6762, Acc: 0.7446 | Val Loss: 0.6789, Acc: 0.7804 | OK Precision: 0.3846, Macro F1: 0.5229
# -> EarlyStopping counter: 37 out of 50
# Epoch [51/500] | Train Loss: 0.7237, Acc: 0.7505 | Val Loss: 0.6373, Acc: 0.8059 | OK Precision: 0.2632, Macro F1: 0.4007
# -> EarlyStopping counter: 38 out of 50
# Epoch [52/500] | Train Loss: 0.6418, Acc: 0.7990 | Val Loss: 0.6853, Acc: 0.8176 | OK Precision: 0.2500, Macro F1: 0.4833
# -> EarlyStopping counter: 39 out of 50
# Epoch [53/500] | Train Loss: 0.6773, Acc: 0.7681 | Val Loss: 0.6679, Acc: 0.7725 | OK Precision: 0.5556, Macro F1: 0.5521
# -> EarlyStopping counter: 40 out of 50
# Epoch [54/500] | Train Loss: 0.6522, Acc: 0.7789 | Val Loss: 0.6425, Acc: 0.7784 | OK Precision: 0.5000, Macro F1: 0.5350
# -> EarlyStopping counter: 41 out of 50
# Epoch [55/500] | Train Loss: 0.6704, Acc: 0.7804 | Val Loss: 0.6659, Acc: 0.7157 | OK Precision: 0.4545, Macro F1: 0.5078
# -> EarlyStopping counter: 42 out of 50
# Epoch [56/500] | Train Loss: 0.6606, Acc: 0.7814 | Val Loss: 0.7044, Acc: 0.8000 | OK Precision: 0.2778, Macro F1: 0.4603
# -> EarlyStopping counter: 43 out of 50
# Epoch [57/500] | Train Loss: 0.7020, Acc: 0.7760 | Val Loss: 0.6607, Acc: 0.8608 | OK Precision: 0.4545, Macro F1: 0.5539
# -> EarlyStopping counter: 44 out of 50
# Epoch [58/500] | Train Loss: 0.6483, Acc: 0.7691 | Val Loss: 0.6793, Acc: 0.8353 | OK Precision: 1.0000, Macro F1: 0.6619
# -> Validation precision improved (0.5888 --> 0.6619).
# Saving classifier head to dino_classifier_head_multiclass_epoch_58.pth
# Epoch [59/500] | Train Loss: 0.6269, Acc: 0.7882 | Val Loss: 0.6701, Acc: 0.8333 | OK Precision: 0.4167, Macro F1: 0.4433
# -> EarlyStopping counter: 1 out of 50
# Epoch [60/500] | Train Loss: 0.6620, Acc: 0.7696 | Val Loss: 0.7066, Acc: 0.7706 | OK Precision: 0.3571, Macro F1: 0.4909
# -> EarlyStopping counter: 2 out of 50
# Epoch [61/500] | Train Loss: 0.6470, Acc: 0.7760 | Val Loss: 0.7031, Acc: 0.8412 | OK Precision: 0.2500, Macro F1: 0.5416
# -> EarlyStopping counter: 3 out of 50
# Epoch [62/500] | Train Loss: 0.7114, Acc: 0.7642 | Val Loss: 0.6337, Acc: 0.7745 | OK Precision: 0.4167, Macro F1: 0.5147
# -> EarlyStopping counter: 4 out of 50
# Epoch [63/500] | Train Loss: 0.6261, Acc: 0.7750 | Val Loss: 0.6643, Acc: 0.8725 | OK Precision: 0.5000, Macro F1: 0.5961
# -> EarlyStopping counter: 5 out of 50
# Epoch [64/500] | Train Loss: 0.7076, Acc: 0.7539 | Val Loss: 0.6542, Acc: 0.7627 | OK Precision: 0.4167, Macro F1: 0.5042
# -> EarlyStopping counter: 6 out of 50
# Epoch [65/500] | Train Loss: 0.6361, Acc: 0.7863 | Val Loss: 0.6234, Acc: 0.7490 | OK Precision: 0.2727, Macro F1: 0.4745
# -> EarlyStopping counter: 7 out of 50
# Epoch [66/500] | Train Loss: 0.6153, Acc: 0.7779 | Val Loss: 0.7645, Acc: 0.8608 | OK Precision: 0.4545, Macro F1: 0.5581
# -> EarlyStopping counter: 8 out of 50
# Epoch [67/500] | Train Loss: 0.6554, Acc: 0.7853 | Val Loss: 0.7768, Acc: 0.6941 | OK Precision: 0.3571, Macro F1: 0.4396
# -> EarlyStopping counter: 9 out of 50
# Epoch [68/500] | Train Loss: 0.6748, Acc: 0.7745 | Val Loss: 0.6713, Acc: 0.7451 | OK Precision: 0.5556, Macro F1: 0.5084
# -> EarlyStopping counter: 10 out of 50
# Epoch [69/500] | Train Loss: 0.6652, Acc: 0.7755 | Val Loss: 0.6138, Acc: 0.8137 | OK Precision: 0.3846, Macro F1: 0.5214
# -> EarlyStopping counter: 11 out of 50
# Epoch [70/500] | Train Loss: 0.6502, Acc: 0.7824 | Val Loss: 0.6125, Acc: 0.7784 | OK Precision: 0.2381, Macro F1: 0.4897
# -> EarlyStopping counter: 12 out of 50
# Epoch [71/500] | Train Loss: 0.6284, Acc: 0.7755 | Val Loss: 0.6375, Acc: 0.7804 | OK Precision: 0.3846, Macro F1: 0.4991
# -> EarlyStopping counter: 13 out of 50
# Epoch [72/500] | Train Loss: 0.6525, Acc: 0.7730 | Val Loss: 0.7119, Acc: 0.8608 | OK Precision: 0.6250, Macro F1: 0.6005
# -> EarlyStopping counter: 14 out of 50
# Epoch [73/500] | Train Loss: 0.6485, Acc: 0.7750 | Val Loss: 0.6778, Acc: 0.6765 | OK Precision: 0.1935, Macro F1: 0.4381
# -> EarlyStopping counter: 15 out of 50
# Epoch [74/500] | Train Loss: 0.6599, Acc: 0.7466 | Val Loss: 0.6657, Acc: 0.6431 | OK Precision: 0.3000, Macro F1: 0.4466
# -> EarlyStopping counter: 16 out of 50
# Epoch [75/500] | Train Loss: 0.6390, Acc: 0.7652 | Val Loss: 0.6634, Acc: 0.7784 | OK Precision: 0.3846, Macro F1: 0.4830
# -> EarlyStopping counter: 17 out of 50
# Epoch [76/500] | Train Loss: 0.6508, Acc: 0.7721 | Val Loss: 0.7083, Acc: 0.7980 | OK Precision: 1.0000, Macro F1: 0.6476
# -> EarlyStopping counter: 18 out of 50
# Epoch [77/500] | Train Loss: 0.6552, Acc: 0.7672 | Val Loss: 0.6806, Acc: 0.7353 | OK Precision: 0.6250, Macro F1: 0.5489
# -> EarlyStopping counter: 19 out of 50
# Epoch [78/500] | Train Loss: 0.6493, Acc: 0.7711 | Val Loss: 0.6718, Acc: 0.7863 | OK Precision: 0.2273, Macro F1: 0.4319
# -> EarlyStopping counter: 20 out of 50
# Epoch [79/500] | Train Loss: 0.6442, Acc: 0.7740 | Val Loss: 0.6441, Acc: 0.8294 | OK Precision: 0.3333, Macro F1: 0.4961
# -> EarlyStopping counter: 21 out of 50
# Epoch [80/500] | Train Loss: 0.6272, Acc: 0.7873 | Val Loss: 0.6194, Acc: 0.7353 | OK Precision: 0.3846, Macro F1: 0.4719
# -> EarlyStopping counter: 22 out of 50
# Epoch [81/500] | Train Loss: 0.6157, Acc: 0.7706 | Val Loss: 0.7124, Acc: 0.7961 | OK Precision: 0.4545, Macro F1: 0.4414
# -> EarlyStopping counter: 23 out of 50
# Epoch [82/500] | Train Loss: 0.6855, Acc: 0.7461 | Val Loss: 0.6685, Acc: 0.7882 | OK Precision: 0.3333, Macro F1: 0.4732
# -> EarlyStopping counter: 24 out of 50
# Epoch [83/500] | Train Loss: 0.6259, Acc: 0.7593 | Val Loss: 0.7247, Acc: 0.7706 | OK Precision: 0.2308, Macro F1: 0.4770
# -> EarlyStopping counter: 25 out of 50
# Epoch [84/500] | Train Loss: 0.6414, Acc: 0.7583 | Val Loss: 0.5785, Acc: 0.7569 | OK Precision: 0.2174, Macro F1: 0.4565
# -> EarlyStopping counter: 26 out of 50
# Epoch [85/500] | Train Loss: 0.6509, Acc: 0.7667 | Val Loss: 0.5716, Acc: 0.7549 | OK Precision: 0.4000, Macro F1: 0.4696
# -> EarlyStopping counter: 27 out of 50
# Epoch [86/500] | Train Loss: 0.6562, Acc: 0.7446 | Val Loss: 0.5775, Acc: 0.7588 | OK Precision: 0.3529, Macro F1: 0.4694
# -> EarlyStopping counter: 28 out of 50
# Epoch [87/500] | Train Loss: 0.6184, Acc: 0.7564 | Val Loss: 0.6483, Acc: 0.7157 | OK Precision: 0.3846, Macro F1: 0.4512
# -> EarlyStopping counter: 29 out of 50
# Epoch [88/500] | Train Loss: 0.6076, Acc: 0.7569 | Val Loss: 0.7072, Acc: 0.6490 | OK Precision: 0.1579, Macro F1: 0.4141
# -> EarlyStopping counter: 30 out of 50
# Epoch [89/500] | Train Loss: 0.6568, Acc: 0.7426 | Val Loss: 0.6709, Acc: 0.7745 | OK Precision: 0.4545, Macro F1: 0.5071
# -> EarlyStopping counter: 31 out of 50
# Epoch [90/500] | Train Loss: 0.6298, Acc: 0.7583 | Val Loss: 0.6490, Acc: 0.7667 | OK Precision: 0.6667, Macro F1: 0.5280
# -> EarlyStopping counter: 32 out of 50
# Epoch [91/500] | Train Loss: 0.6140, Acc: 0.7716 | Val Loss: 0.6781, Acc: 0.6882 | OK Precision: 0.4167, Macro F1: 0.5103
# -> EarlyStopping counter: 33 out of 50
# Epoch [92/500] | Train Loss: 0.6043, Acc: 0.7770 | Val Loss: 0.8320, Acc: 0.6608 | OK Precision: 0.5000, Macro F1: 0.4574
# -> EarlyStopping counter: 34 out of 50
# Epoch [93/500] | Train Loss: 0.6636, Acc: 0.7775 | Val Loss: 0.7498, Acc: 0.7686 | OK Precision: 0.1875, Macro F1: 0.4453
# -> EarlyStopping counter: 35 out of 50
# Epoch [94/500] | Train Loss: 0.6720, Acc: 0.7618 | Val Loss: 0.6078, Acc: 0.7961 | OK Precision: 0.4545, Macro F1: 0.5182
# -> EarlyStopping counter: 36 out of 50
# Epoch [95/500] | Train Loss: 0.6454, Acc: 0.7686 | Val Loss: 1.1004, Acc: 0.8529 | OK Precision: 0.0000, Macro F1: 0.4228
# -> EarlyStopping counter: 37 out of 50
# Epoch [96/500] | Train Loss: 0.6245, Acc: 0.7833 | Val Loss: 0.6256, Acc: 0.7176 | OK Precision: 0.4167, Macro F1: 0.4769
# -> EarlyStopping counter: 38 out of 50
# Epoch [97/500] | Train Loss: 0.6260, Acc: 0.7740 | Val Loss: 0.7886, Acc: 0.8549 | OK Precision: 0.4545, Macro F1: 0.4573
# -> EarlyStopping counter: 39 out of 50
# Epoch [98/500] | Train Loss: 0.6873, Acc: 0.7441 | Val Loss: 0.7153, Acc: 0.5627 | OK Precision: 0.3571, Macro F1: 0.4369
# -> EarlyStopping counter: 40 out of 50
# Epoch [99/500] | Train Loss: 0.5911, Acc: 0.7701 | Val Loss: 0.7024, Acc: 0.6706 | OK Precision: 0.3846, Macro F1: 0.4695
# -> EarlyStopping counter: 41 out of 50
# Epoch [100/500] | Train Loss: 0.5710, Acc: 0.7858 | Val Loss: 0.6785, Acc: 0.7961 | OK Precision: 0.3125, Macro F1: 0.4647
# -> EarlyStopping counter: 42 out of 50
# Epoch [101/500] | Train Loss: 0.5988, Acc: 0.7696 | Val Loss: 0.7808, Acc: 0.7569 | OK Precision: 0.3571, Macro F1: 0.4754
# -> EarlyStopping counter: 43 out of 50
# Epoch [102/500] | Train Loss: 0.6629, Acc: 0.7716 | Val Loss: 0.6669, Acc: 0.7294 | OK Precision: 0.2778, Macro F1: 0.4295
# -> EarlyStopping counter: 44 out of 50
# Epoch [103/500] | Train Loss: 0.6312, Acc: 0.7578 | Val Loss: 0.6335, Acc: 0.7333 | OK Precision: 0.3846, Macro F1: 0.4625
# -> EarlyStopping counter: 45 out of 50
# Epoch [104/500] | Train Loss: 0.6342, Acc: 0.7662 | Val Loss: 0.6504, Acc: 0.7784 | OK Precision: 0.5000, Macro F1: 0.5014
# -> EarlyStopping counter: 46 out of 50
# Epoch [105/500] | Train Loss: 0.6148, Acc: 0.7672 | Val Loss: 0.7217, Acc: 0.7059 | OK Precision: 0.4545, Macro F1: 0.4404
# -> EarlyStopping counter: 47 out of 50
# Epoch [106/500] | Train Loss: 0.6941, Acc: 0.7623 | Val Loss: 0.6529, Acc: 0.7725 | OK Precision: 0.3750, Macro F1: 0.4629
# -> EarlyStopping counter: 48 out of 50
# Epoch [107/500] | Train Loss: 0.6149, Acc: 0.7946 | Val Loss: 0.6456, Acc: 0.7529 | OK Precision: 0.3000, Macro F1: 0.4780
# -> EarlyStopping counter: 49 out of 50
# Epoch [108/500] | Train Loss: 0.5841, Acc: 0.7858 | Val Loss: 0.6161, Acc: 0.7804 | OK Precision: 0.2609, Macro F1: 0.4674
# -> EarlyStopping counter: 50 out of 50
# Early stopping triggered. Training stopped.

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# 1. Ensure the model is in evaluation mode
model.eval()

# 2. Lists to store all our predictions and actual ground truths
all_preds = []
all_labels = []

print("Running inference on the validation set...")

# 3. Pass the val_loader through the model without tracking gradients
with torch.no_grad():
    for pixel_values, patch_mask, labels, laplacian_tensor in val_loader:
        pixel_values = pixel_values.to(device)
        patch_mask = patch_mask.to(device)
        laplacian_tensor = laplacian_tensor.to(device)

        # Get raw logits
        logits = model(pixel_values, patch_mask, laplacian_tensor)
        
        # Get the predicted class index
        preds = torch.argmax(logits, dim=1)
        
        # Move back to CPU and append to our lists
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Define the exact class names and their corresponding index (0 to 6)
class_names = ['o', 'sf', 'mf', 'xf', 'sn', 'mn', 'xn']
class_indices = [0, 1, 2, 3, 4, 5, 6]

# 4. Print the Classification Report
print("\n--- Classification Report ---")
print(classification_report(all_labels, all_preds, 
                            labels=class_indices,       # <--- ADDED THIS
                            target_names=class_names, 
                            zero_division=0))

# 5. Generate the Confusion Matrix
cm = confusion_matrix(all_labels, all_preds, labels=class_indices) # <--- ADDED THIS

# 6. Plot using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, 
            yticklabels=class_names,
            annot_kws={"size": 14}) # Make numbers larger

plt.title('Validation Set Confusion Matrix', fontsize=16)
plt.xlabel('Predicted Class', fontsize=14)
plt.ylabel('True Class', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12, rotation=0)
plt.tight_layout()
plt.show()

wandb.log({"validation_confusion_matrix": wandb.Image(plt)})

wandb.finish()
# Out:
# Running inference on the validation set...
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            o       0.26      1.00      0.41         6
#           sf       0.96      0.81      0.88       432
#           mf       0.34      0.59      0.43        59
#           xf       0.31      0.38      0.34        13
#           sn       0.00      0.00      0.00         0
#           mn       0.00      0.00      0.00         0
#           xn       0.00      0.00      0.00         0
#
#     accuracy                           0.78       510
#    macro avg       0.27      0.40      0.30       510
# weighted avg       0.86      0.78      0.81       510
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>early_stopping_counter</td><td>▁▁▁▂▁▁▁▁▂▂▃▃▃▄▄▄▅▅▅▆▆▇▇▁▁▂▂▂▃▃▄▄▄▅▅▅▇▇██</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▆▆▆▆▇▇▇▇████</td></tr><tr><td>learning_rate</td><td>██████▇▇▇▇▇▇▇▇▇▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▁▁</td></tr><tr><td>train/accuracy</td><td>▁▂▃▂▁▄▅▃▄▅▃▃▆▃█▆▆▆▇▅▅▆▅▆▅▆▄▄▄▅▆▅▆▃▅▅▅▄▅█</td></tr><tr><td>train/loss</td><td>█▆▅▅▄▄▃▃▃▃▃▃▃▃▂▃▃▂▂▂▃▂▂▂▂▂▂▂▁▂▂▂▁▂▂▃▂▂▁▁</td></tr><tr><td>val/accuracy</td><td>▃▁▅▂▅▅▄▄▄█▇▇▇▇▇▇▇▇█▇▆▇▆▇█▇▆▆█▆█▅▆▇▆▅▆▆▅▆</td></tr><tr><td>val/loss</td><td>▆▅▂▃▃▅▂▅▂▃▂▃▂▂▂▂▃▂▃▂▂▄▂▂▂▃▂▂▃▂▃▂▁▁▁█▄▃▂▂</td></tr><tr><td>val/macro_f1</td><td>▁▆▃▅▇▂▃▅▄▆▃▅▄▆▆▃▄▅▅▅▅▆▄▆▅▅▇█▅▄▅▆▄▄▅▅▄▄▅▅</td></tr><tr><td>val/ok_precision</td><td>▁█▅▄▄▁▅▅▄▅▅▄▂▆▃▃▅▄▇▄▇▆▄▆▆▇▆▃▂▅▃▅▆▆▅▇▂▅▇▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>early_stopping_counter</td><td>49</td></tr><tr><td>epoch</td><td>108</td></tr><tr><td>learning_rate</td><td>0.00889</td></tr><tr><td>train/accuracy</td><td>0.78578</td></tr><tr><td>train/loss</td><td>0.58407</td></tr><tr><td>val/accuracy</td><td>0.78039</td></tr><tr><td>val/loss</td><td>0.61607</td></tr><tr><td>val/macro_f1</td><td>0.46742</td></tr><tr><td>val/ok_precision</td><td>0.26087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vith16plus-multiclass-run1</strong> at: <a href='https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection/runs/zk0n6l48' target="_blank">https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection/runs/zk0n6l48</a><br> View project at: <a href='https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection' target="_blank">https://wandb.ai/mingjiehu5-nanyang-technological-university-singapore/dinov3-blur-detection</a><br>Synced 4 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260604_181916-zk0n6l48/logs</code>

# %% [markdown]
# ### Predict Unseen Dataset
